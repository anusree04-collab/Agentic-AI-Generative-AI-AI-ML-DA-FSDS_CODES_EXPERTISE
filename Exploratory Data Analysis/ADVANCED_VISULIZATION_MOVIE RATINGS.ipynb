# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\K anusree'

# %%
movies = pd.read_csv(r"C:\Users\K anusree\OneDrive\Desktop\FSDS\19th, 20th, 21st - EDA\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1/Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  RottenTomatoesRatings  AudienceRatings  \
# 0    (500) Days of Summer      Comedy                     87               81
# 1              10,000 B.C.  Adventure                      9               44
# 2               12 Rounds      Action                     30               52
# 3                127 Hours  Adventure                     93               84
# 4                17 Again      Comedy                     55               70
# ..                     ...        ...                    ...              ...
# 554          Your Highness     Comedy                     26               36
# 555        Youth in Revolt     Comedy                     68               52
# 556                 Zodiac   Thriller                     89               73
# 557            Zombieland      Action                     90               87
# 558              Zookeeper     Comedy                     14               42
#
#      Budget  Year of release
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoesRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy                     87               81
# 1            10,000 B.C.  Adventure                      9               44
# 2             12 Rounds      Action                     30               52
# 3              127 Hours  Adventure                     93               84
# 4              17 Again      Comedy                     55               70
#
#    Budget  Year of release
# 0       8             2009
# 1     105             2008
# 2      20             2009
# 3      18             2010
# 4      20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  RottenTomatoesRatings  AudienceRatings  \
# 554    Your Highness    Comedy                     26               36
# 555  Youth in Revolt    Comedy                     68               52
# 556           Zodiac  Thriller                     89               73
# 557      Zombieland     Action                     90               87
# 558        Zookeeper    Comedy                     14               42
#
#      Budget  Year of release
# 554      50             2011
# 555      18             2009
# 556      65             2007
# 557      24             2009
# 558      80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'RottenTomatoesRatings', 'AudienceRatings', 'Budget',
#        'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Film                   559 non-null    object
#  1   Genre                  559 non-null    object
#  2   RottenTomatoesRatings  559 non-null    int64
#  3   AudienceRatings        559 non-null    int64
#  4   Budget                 559 non-null    int64
#  5   Year of release        559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        RottenTomatoesRatings  AudienceRatings      Budget  Year of release
# count             559.000000       559.000000  559.000000       559.000000
# mean               47.309481        58.744186   50.236136      2009.152057
# std                26.413091        16.826887   48.731817         1.362632
# min                 0.000000         0.000000    0.000000      2007.000000
# 25%                25.000000        47.000000   20.000000      2008.000000
# 50%                46.000000        58.000000   35.000000      2009.000000
# 75%                70.000000        72.000000   65.000000      2010.000000
# max                97.000000        96.000000  300.000000      2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoesRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy                     87               81
# 1            10,000 B.C.  Adventure                      9               44
# 2             12 Rounds      Action                     30               52
# 3              127 Hours  Adventure                     93               84
# 4              17 Again      Comedy                     55               70
#
#    Budget  Year of release
# 0       8             2009
# 1     105             2008
# 2      20             2009
# 3      18             2010
# 4      20             2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Film                   559 non-null    object
#  1   Genre                  559 non-null    object
#  2   RottenTomatoesRatings  559 non-null    int64
#  3   AudienceRatings        559 non-null    int64
#  4   Budget                 559 non-null    int64
#  5   Year of release        559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies['Year of release'] = movies['Year of release'].astype('category')

# %%
movies.columns.tolist()
# Out:
# ['Film',
#  'Genre',
#  'RottenTomatoesRatings',
#  'AudienceRatings',
#  'Budget',
#  'Year of release']

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies['Year of release']
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year of release, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Film                   559 non-null    object
#  1   Genre                  559 non-null    category
#  2   RottenTomatoesRatings  559 non-null    int64
#  3   AudienceRatings        559 non-null    int64
#  4   Budget (million $)     559 non-null    int64
#  5   Year of release        559 non-null    category
# dtypes: category(2), int64(3), object(1)
# memory usage: 19.2+ KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        RottenTomatoesRatings  AudienceRatings      Budget
# count             559.000000       559.000000  559.000000
# mean               47.309481        58.744186   50.236136
# std                26.413091        16.826887   48.731817
# min                 0.000000         0.000000    0.000000
# 25%                25.000000        47.000000   20.000000
# 50%                46.000000        58.000000   35.000000
# 75%                70.000000        72.000000   65.000000
# max                97.000000        96.000000  300.000000

# %%
movies.columns.tolist()
# Out:
# ['Film',
#  'Genre',
#  'RottenTomatoesRatings',
#  'AudienceRatings',
#  'Budget',
#  'Year of release']

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'RottenTomatoesRatings', 'AudienceRatings', 'Budget',
#        'Year of release'],
#       dtype='object')

# %%
j = sns.jointplot( data = movies, x = 'RottenTomatoesRatings', y = 'AudienceRatings')

# %%
j = sns.jointplot( data = movies, x = 'RottenTomatoesRatings', y = 'AudienceRatings',kind='hex')

# %%
j = sns.jointplot( data = movies, x = 'RottenTomatoesRatings', y = 'AudienceRatings',kind='reg')

# %%
m1 = sns.distplot(movies.AudienceRatings)

# %%
m1 = sns.distplot(movies.AudienceRatings,bins=18)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRatings, bins = 15)

# %%
n1 = plt.hist(movies.AudienceRatings, bins=15)

# %%
sns.set_style('white')
n1 = plt.hist(movies.AudienceRatings, bins=20)

# %%
n1 = plt.hist(movies.RottenTomatoesRatings, bins=20)

# %%
plt.hist(movies.Budget)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].Budget)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoesRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy                     87               81
# 1            10,000 B.C.  Adventure                      9               44
# 2             12 Rounds      Action                     30               52
# 3              127 Hours  Adventure                     93               84
# 4              17 Again      Comedy                     55               70
#
#    Budget Year of release
# 0       8            2009
# 1     105            2008
# 2      20            2009
# 3      18            2010
# 4      20            2009

# %%
plt.hist(movies[movies.Genre == 'Action'].Budget, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].Budget, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].Budget, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].Budget,
          movies[movies.Genre == 'Drama'].Budget, 
          movies[movies.Genre == 'Thriller'].Budget,
          movies[movies.Genre == 'Comedy'].Budget],
         bins = 20, stacked = True)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='RottenTomatoesRatings', y='AudienceRatings',\
                 fit_reg=False)

# %%
vis1 = sns.lmplot(data=movies, x='RottenTomatoesRatings', y='AudienceRatings',\
                 fit_reg=False, hue = 'Genre')

# %%
k1 = sns.kdeplot(movies.RottenTomatoesRatings)

# %%
k1 = sns.kdeplot(movies.AudienceRatings)

# %%
k1 = sns.kdeplot(
    data = movies,
    x='RottenTomatoesRatings',
    y='AudienceRatings'
)

# %%
k1 = sns.kdeplot(
    data = movies,
    x='RottenTomatoesRatings',
    y='AudienceRatings',
    shade = True,
    shade_lowest=False,
    cmap='Reds',
)

# %%
k1 = sns.kdeplot(
    data = movies,
    x='RottenTomatoesRatings',
    y='AudienceRatings',
    shade_lowest=False,
    cmap='Greens_r',
)

# %%
sns.set_style('dark'),
k1 = sns.kdeplot(
    data = movies,
    x='Budget',
    y='AudienceRatings',
    shade_lowest=False,
    cmap='Greens_r',
)

# %%
sns.set_style('dark'),
k1 = sns.kdeplot(
    data=movies,
    x='Budget',
    y='AudienceRatings',
)

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
w = sns.boxplot(data=movies, x='Genre', y = 'RottenTomatoesRatings')

# %%
z = sns.violinplot(data=movies, x='Genre', y = 'RottenTomatoesRatings')

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year of release', y = 'RottenTomatoesRatings')

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year of release', hue = 'Genre')

# %%
plt.scatter(movies.RottenTomatoesRatings,movies.AudienceRatings)

# %%
g = sns.FacetGrid (movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
g = g.map(plt.scatter, 'RottenTomatoesRatings', 'AudienceRatings' )

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
g = g.map(plt.hist, 'Budget')

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'RottenTomatoesRatings', 'AudienceRatings',**kws )
