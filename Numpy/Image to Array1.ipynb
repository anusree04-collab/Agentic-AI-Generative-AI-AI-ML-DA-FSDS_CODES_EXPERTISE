# %% [markdown]
# CONVERTING IMAGE TO ARRAY

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
image=Image.open(r'C:\Users\K anusree\OneDrive\flower.jpg')
image

# %%
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
flower_array=np.asarray(image)
flower_array
# Out:
# array([[[ 0, 60,  4],
#         [ 0, 61,  5],
#         [ 0, 63,  7],
#         ...,
#         [ 0, 57,  0],
#         [ 0, 56,  0],
#         [ 0, 56,  0]],
#
#        [[ 0, 60,  4],
#         [ 0, 61,  5],
#         [ 0, 63,  7],
#         ...,
#         [ 0, 58,  1],
#         [ 0, 57,  0],
#         [ 0, 57,  0]],
#
#        [[ 0, 60,  4],
#         [ 0, 61,  5],
#         [ 0, 63,  7],
#         ...,
#         [ 0, 58,  1],
#         [ 0, 58,  1],
#         [ 0, 58,  1]],
#
#        ...,
#
#        [[26, 98, 24],
#         [24, 98, 23],
#         [23, 95, 19],
#         ...,
#         [ 0, 50,  0],
#         [ 0, 50,  0],
#         [ 0, 50,  0]],
#
#        [[32, 98, 26],
#         [29, 97, 24],
#         [29, 95, 21],
#         ...,
#         [ 0, 50,  0],
#         [ 0, 50,  0],
#         [ 0, 50,  0]],
#
#        [[35, 98, 27],
#         [33, 96, 25],
#         [31, 95, 21],
#         ...,
#         [ 0, 50,  0],
#         [ 0, 50,  0],
#         [ 0, 50,  0]]], shape=(4000, 6000, 3), dtype=uint8)

# %%
plt.imshow(image)
plt.show()

# %%
from PIL import Image
import numpy as np
img = Image.open(r"C:\Users\K anusree\OneDrive\flower.jpg")
img=img.resize((800,533))
arr=np.array(img)
print("Array shape:",arr.shape)
# Out:
# Array shape: (533, 800, 3)
