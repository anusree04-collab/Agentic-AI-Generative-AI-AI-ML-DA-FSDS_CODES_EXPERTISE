# %%
import pandas as pd
import os
path=r"C:\Users\K anusree\oneDrive\Desktop\FSDS\Pandas\data.xlsx"
print(os.path.exists(path))
# Out:
# True

# %%
path=pd.read_excel(r"C:\Users\K anusree\OneDrive\Desktop\FSDS\Pandas\data.xlsx")
print(path)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(path)
# Out:
# 195

# %%
type(path)
# Out:
# pandas.core.frame.DataFrame

# %%
path.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(path.columns)
# Out:
# 5

# %%
path.shape
# Out:
# (195, 5)

# %%
path.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
path.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
path.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
path.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
path.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
type(path)
# Out:
# pandas.core.frame.DataFrame

# %%
path.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
path.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
path.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
path.head(5)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
path.tail(3)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
path["BirthRate"]
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
path["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
path[["BirthRate","InternetUsers"]]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %% [markdown]
# LETS SPLIT THE DATA INTO NUMERICAL & CATEGORICAL

# %%
path.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
path_numeric_data = path[['BirthRate', 'InternetUsers']]

# %%
path_numeric_data
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
path_numeric_data.head()
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9
# 2     45.985           19.1
# 3     12.877           57.2
# 4     11.044           88.0

# %%
path_numeric_data.tail()
# Out:
#      BirthRate  InternetUsers
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5

# %%
path_categorical_data = path[['CountryName', 'CountryCode', 'IncomeGroup']]
path_categorical_data
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
print(path.shape)
print(path_numeric_data.shape)
print(path_categorical_data.shape)
# Out:
# (195, 5)
# (195, 2)
# (195, 3)

# %% [markdown]
# SLICING IN PANDAS

# %%
path[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path[2:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# ..                   ...
# ...

# %%
path[192:]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
path[4:25]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# ...

# %%
path[90:]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 90         Kazakhstan         KAZ     22.730           54.0
# 91              Kenya         KEN     35.194           39.0
# 92    Kyrgyz Republic         KGZ     27.200           23.0
# 93           Cambodia         KHM     24.462            6.8
# 94           Kiribati         KIR     29.044           11.5
# ..                ...         ...        ...            ...
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 90   Upper middle income
# 91   Lower middle income
# 92   Lower middle income
# 93            Low income
# 94   Lower middle income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
path[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
path[::-6]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715      18.500000
# 188    West Bank and Gaza         PSE     30.394      46.600000
# 182            Uzbekistan         UZB     22.500      38.200000
# 176                Turkey         TUR     16.836      46.250000
# 170            Tajikistan         TJK     30.792      16.000000
# 164             Swaziland         SWZ     30.093      24.700000
# 158           South Sudan         SSD     37.126      14.100000
# 152             Singapore         SGP      9.300      81.000000
# 146               Romania         ROU      8.800      49.764500
# 140                Poland         POL      9.600      62.849200
# 134                  Oman         OMN     20.419      66.450000
# 128               Nigeria         NGA     40.045      38.000000
# 122             Mauritius         MUS     10.900      39.000000
# 116                 Malta         MLT      9.500      68.913800
# ...

# %%
path[:-6]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244           78.9
# 1              Afghanistan         AFG     35.253            5.9
# 2                   Angola         AGO     45.985           19.1
# 3                  Albania         ALB     12.877           57.2
# 4     United Arab Emirates         ARE     11.044           88.0
# ..                     ...         ...        ...            ...
# 184          Venezuela, RB         VEN     19.842           54.9
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path[25:99:2]
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 25                  Barbados         BRB     12.188        73.0000
# 27                    Bhutan         BTN     18.134        29.9000
# 29  Central African Republic         CAF     34.076         3.5000
# 31               Switzerland         CHE     10.200        86.3400
# 33                     China         CHN     12.100        45.8000
# 35                  Cameroon         CMR     37.236         6.4000
# 37                  Colombia         COL     16.076        51.7000
# 39                Cabo Verde         CPV     21.625        37.5000
# 41                      Cuba         CUB     10.400        27.9300
# 43                    Cyprus         CYP     11.436        65.4548
# 45                   Germany         DEU      8.500        84.1700
# 47                   Denmark         DNK     10.000        94.6297
# 49                   Algeria         DZA     24.738        16.5000
# ...

# %%
path
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path[:100]
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                  Aruba         ABW     10.244          78.90
# 1            Afghanistan         AFG     35.253           5.90
# 2                 Angola         AGO     45.985          19.10
# 3                Albania         ALB     12.877          57.20
# 4   United Arab Emirates         ARE     11.044          88.00
# ..                   ...         ...        ...            ...
# 95           Korea, Rep.         KOR      8.600          84.77
# 96                Kuwait         KWT     20.575          75.46
# 97               Lao PDR         LAO     27.051          12.50
# 98               Lebanon         LBN     13.426          70.50
# 99               Liberia         LBR     35.521           3.20
#
#             IncomeGroup
# 0           High income
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# ..                  ...
# 95          High income
# ...

# %%
path[:200]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
path.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
path.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
path.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
#added a new column
path['newcolumn'] = path.BirthRate * path.InternetUsers
path
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  newcolumn
# 0            High income   808.2516
# 1             Low income   207.9927
# 2    Upper middle income   878.3135
# 3    Upper middle income   736.5644
# ...

# %%
path.head(5)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  newcolumn
# 0          High income   808.2516
# 1           Low income   207.9927
# 2  Upper middle income   878.3135
# 3  Upper middle income   736.5644
# 4          High income   971.8720

# %%
len(path.columns)
# Out:
# 6

# %%
# to drop a column
path = path.drop('newcolumn',axis = 1)
path
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
path
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path.InternetUsers<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
len(path[path.InternetUsers<2])
# Out:
# 9

# %%
path.BirthRate>40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
path[path.BirthRate>40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
path[(path.BirthRate>40)&(path.InternetUsers<2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
path[(path.IncomeGroup=='High Income')]
path
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path[(path.IncomeGroup=='Low Income')]

# %%
path
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
path.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
path.IncomeGroup.nunique()
# Out:
# 4

# %%
import seaborn as sns 
print(sns.__version__)
# Out:
# 0.13.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=6,3
import warnings
warnings.filterwarnings('ignore')

# %%
path.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
path["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
min(path["InternetUsers"])
# Out:
# 0.9

# %%
max(path["InternetUsers"])
# Out:
# 96.5468

# %%
vis1=sns.distplot(path["InternetUsers"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vis1=sns.distplot(path["InternetUsers"],bins=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vis2=sns.boxplot(x="IncomeGroup",y="BirthRate",data=path)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vis3=sns.lmplot(x="InternetUsers",y="BirthRate",data=path)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vis3=sns.lmplot(x="InternetUsers",y="BirthRate",data=path,fit_reg=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vis3=sns.lmplot(x="InternetUsers",y="BirthRate",data=path,fit_reg=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vis3=sns.lmplot(x="InternetUsers",y="BirthRate",data=path,fit_reg=True,hue="IncomeGroup")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
